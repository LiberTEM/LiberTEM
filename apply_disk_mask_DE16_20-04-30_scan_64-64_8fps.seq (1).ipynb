# %%
import matplotlib.pyplot as plt
import libertem.api as lt
import numpy as np
from matplotlib import colors
from libertem import masks
from libertem.udf.sum import SumUDF

# %%
# %matplotlib nbagg

# %% [markdown]
# # Connection
# This starts a local cluster that is accessible through ctx.

# %%
ctx = lt.Context()
# Out:
# d:\gitmine\libertem\venv\lib\site-packages\distributed\node.py:160: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 57822 instead
#   warnings.warn(

# %%
params = {'path': 'D:\\gitMine\\LiberTEM\\data\\DE16_20-04-30_scan_64-64_8fps/DE16_20-04-30_scan_64-64_8fps.seq',
          'nav_shape': [16, 16], 'sig_shape': (1024, 1024), 'sync_offset': 0}
ds = ctx.load("SEQ", **params)

# %% [markdown]
# # SUM Analysis
#
# from this value and the dataset's dtype using: meth: `numpy.result_type`.
# <pre > Sum up frames, preserving the signal dimension
#
# Parameters
# ----------
# dtype: numpy.dtype, optional
# Preferred dtype for computation, default 'float32'. The actual dtype will be determined
# See also: ref: `udf dtype`.
#
# Examples
# --------
# >> > udf = SumUDF()
# >> > result = ctx.run_udf(dataset=dataset, udf=udf)
# >> > np.array(result["intensity"]).shape
# (32, 32) < /pre >

# %%
roi = None
sum_udf = SumUDF()
print(sum_udf)
sum_result = ctx.run_udf(dataset=ds, udf=sum_udf, roi=roi)
# Out:
# <libertem.udf.sum.SumUDF object at 0x0000017F39FE5790>

# %%
plt.figure()
plt.imshow(sum_result['intensity'], norm=colors.LogNorm())
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
