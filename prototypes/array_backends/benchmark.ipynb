# %%
import numpy as np
import cupy

from libertem.common.array_backends import (
    benchmark_conversions, CPU_BACKENDS, BACKENDS,
    NUMPY, NUMPY_MATRIX, CUDA, CUPY, SPARSE_COO, SPARSE_GCXS, SPARSE_DOK, SCIPY_COO, SCIPY_CSR, SCIPY_CSC,
    CUPY_SCIPY_COO, CUPY_SCIPY_CSR, CUPY_SCIPY_CSC
)

# %%
b = benchmark_conversions(
    shape=(32, 512, 512),
    dtype=np.float32,
    density=0.1,
    backends=BACKENDS
)
# Out:
# scipy.sparse.csc_matrix scipy.sparse.csc_matrix (6e-07, 1e-06, 6.8e-07)
# scipy.sparse.csc_matrix sparse.DOK (0.7718745, 0.8121308, 0.79008641)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.0149673, 0.0168483, 0.01557962)
# scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.0052122, 0.005885, 0.00550373)
# scipy.sparse.csc_matrix cupy (0.062257, 0.0768854, 0.07368527)
# scipy.sparse.csc_matrix cuda (0.0062332, 0.0067999, 0.00645836)
# scipy.sparse.csc_matrix numpy (0.0062331, 0.0071447, 0.00646419)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.0077993, 0.0105866, 0.00894698)
# scipy.sparse.csc_matrix numpy.matrix (0.055844, 0.0903307, 0.06175063)
# scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.0087591, 0.0096266, 0.00913096)
# scipy.sparse.csc_matrix sparse.GCXS (1.63e-05, 2.18e-05, 1.715e-05)
# scipy.sparse.csc_matrix sparse.COO (0.1025055, 0.117259, 0.10771111)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (0.0023456, 0.0041815, 0.00276772)
# sparse.DOK scipy.sparse.csc_matrix (0.411587, 0.4511783, 0.42924186)
# sparse.DOK sparse.DOK (7e-07, 1.1e-06, 8.1e-07)
# sparse.DOK cupyx.scipy.sparse.coo_matrix (0.4315861, 0.4838373, 0.45422632)
# sparse.DOK scipy.sparse.csr_matrix (0.3971951, 0.4293139, 0.41378311)
# sparse.DOK cupy (0.1122905, 0.128137, 0.12193486)
# sparse.DOK cuda (0.111658, 0.1296881, 0.11697014)
# sparse.DOK numpy (0.1084633, 0.1198275, 0.111815)
# sparse.DOK cupyx.scipy.sparse.csr_matrix (0.408098, 0.5490742, 0.45438094)
# sparse.DOK numpy.matrix (0.119469, 0.1303484, 0.12303009)
# sparse.DOK scipy.sparse.coo_matrix (0.3938161, 0.4202008, 0.40668993)
# sparse.DOK sparse.GCXS (0.4064663, 0.4503498, 0.42601204)
# sparse.DOK sparse.COO (0.3825154, 0.4116871, 0.39792751)
# sparse.DOK cupyx.scipy.sparse.csc_matrix (0.4103662, 0.4424192, 0.42898774)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.0511635, 0.0534329, 0.0520641)
# cupyx.scipy.sparse.coo_matrix sparse.DOK (0.6757347, 0.7299439, 0.69566436)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (7e-07, 1.1e-06, 8e-07)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.0508648, 0.052762, 0.05163085)
# cupyx.scipy.sparse.coo_matrix cupy (0.1136893, 0.11482, 0.11410962)
# cupyx.scipy.sparse.coo_matrix cuda (0.0125765, 0.0138053, 0.01298642)
# cupyx.scipy.sparse.coo_matrix numpy (0.01247, 0.0146565, 0.01314296)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.0475176, 0.0487095, 0.04786648)
# cupyx.scipy.sparse.coo_matrix numpy.matrix (0.0191615, 0.0212715, 0.01981244)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.coo_matrix (0.0064531, 0.0078099, 0.00711411)
# cupyx.scipy.sparse.coo_matrix sparse.GCXS (0.0507181, 0.0532804, 0.0518312)
# cupyx.scipy.sparse.coo_matrix sparse.COO (0.0201214, 0.0256605, 0.0226392)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.0477696, 0.0484309, 0.04807331)
# scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.0092803, 0.0152718, 0.01132071)
# scipy.sparse.csr_matrix sparse.DOK (0.6834197, 0.7037879, 0.69419015)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.0133901, 0.0407213, 0.03507685)
# scipy.sparse.csr_matrix scipy.sparse.csr_matrix (7e-07, 1.1e-06, 8.1e-07)
# scipy.sparse.csr_matrix cupy (0.0728901, 0.0754863, 0.0736361)
# scipy.sparse.csr_matrix cuda (0.0057244, 0.0115205, 0.00702799)
# scipy.sparse.csr_matrix numpy (0.0058489, 0.0063975, 0.00613211)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (0.0020016, 0.0024038, 0.00214472)
# scipy.sparse.csr_matrix numpy.matrix (0.0124076, 0.0293384, 0.01560373)
# scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.0074569, 0.008948, 0.00780115)
# scipy.sparse.csr_matrix sparse.GCXS (1.68e-05, 2.06e-05, 1.791e-05)
# scipy.sparse.csr_matrix sparse.COO (0.0164827, 0.0188443, 0.01731952)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.0114921, 0.0160604, 0.01247452)
# cupy scipy.sparse.csc_matrix (0.0854265, 0.0956943, 0.08765124)
# cupy sparse.DOK (0.4245034, 0.4784282, 0.44793429)
# cupy cupyx.scipy.sparse.coo_matrix (0.0080447, 0.0847164, 0.01578986)
# cupy scipy.sparse.csr_matrix (0.0797719, 0.0865819, 0.08288962)
# cupy cupy (7e-07, 1.2e-06, 8.1e-07)
# cupy cuda (0.0115776, 0.0118239, 0.011692)
# cupy numpy (0.0116881, 0.017103, 0.01315366)
# cupy cupyx.scipy.sparse.csr_matrix (0.0106474, 0.0108037, 0.01067939)
# cupy numpy.matrix (0.018068, 0.0272343, 0.01975819)
# cupy scipy.sparse.coo_matrix (0.0764105, 0.0823749, 0.07855287)
# cupy sparse.GCXS (0.0931523, 0.1101838, 0.09928033)
# cupy sparse.COO (0.0619827, 0.0884264, 0.07420958)
# cupy cupyx.scipy.sparse.csc_matrix (0.0122947, 0.0294312, 0.01580088)
# cuda scipy.sparse.csc_matrix (0.0724834, 0.0798114, 0.07511825)
# cuda sparse.DOK (0.4173975, 0.454364, 0.42874134)
# cuda cupyx.scipy.sparse.coo_matrix (0.0209867, 0.0261551, 0.02223272)
# cuda scipy.sparse.csr_matrix (0.0690918, 0.0773876, 0.07167406)
# cuda cupy (0.0025456, 0.0103259, 0.0062838)
# cuda cuda (7e-07, 1.1e-06, 7.5e-07)
# cuda numpy (7e-07, 9e-07, 8e-07)
# cuda cupyx.scipy.sparse.csr_matrix (0.021641, 0.0225984, 0.02201833)
# cuda numpy.matrix (0.0061801, 0.0127334, 0.00721113)
# cuda scipy.sparse.coo_matrix (0.0651352, 0.0726403, 0.06756767)
# cuda sparse.GCXS (0.0831439, 0.1074568, 0.08923092)
# cuda sparse.COO (0.0498761, 0.0656985, 0.05519825)
# cuda cupyx.scipy.sparse.csc_matrix (0.0201642, 0.0618218, 0.03305383)
# numpy scipy.sparse.csc_matrix (0.0724016, 0.0837357, 0.07595573)
# numpy sparse.DOK (0.4041013, 0.455719, 0.42557287)
# numpy cupyx.scipy.sparse.coo_matrix (0.0215808, 0.1402537, 0.03367578)
# numpy scipy.sparse.csr_matrix (0.0708931, 0.0806069, 0.07286735)
# numpy cupy (0.0025643, 0.0104795, 0.00426659)
# numpy cuda (7e-07, 1.1e-06, 8.1e-07)
# numpy numpy (7e-07, 9e-07, 7.6e-07)
# numpy cupyx.scipy.sparse.csr_matrix (0.0217659, 0.0225071, 0.02202718)
# numpy numpy.matrix (0.0062072, 0.0133171, 0.00715483)
# numpy scipy.sparse.coo_matrix (0.064308, 0.0760751, 0.06798563)
# numpy sparse.GCXS (0.0823947, 0.1005764, 0.08982199)
# numpy sparse.COO (0.0502593, 0.0595826, 0.05319294)
# numpy cupyx.scipy.sparse.csc_matrix (0.0198927, 0.0615847, 0.03394102)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.0056663, 0.0079601, 0.00628662)
# cupyx.scipy.sparse.csr_matrix sparse.DOK (0.6790675, 0.7028662, 0.6935086)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.0077038, 0.0483798, 0.01812139)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csr_matrix (0.0027778, 0.0031424, 0.00290519)
# cupyx.scipy.sparse.csr_matrix cupy (0.0706119, 0.0733839, 0.07112426)
# cupyx.scipy.sparse.csr_matrix cuda (0.0086988, 0.0091623, 0.0088542)
# cupyx.scipy.sparse.csr_matrix numpy (0.0086527, 0.0106318, 0.00929009)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (7e-07, 1.6e-06, 8.4e-07)
# cupyx.scipy.sparse.csr_matrix numpy.matrix (0.0170106, 0.0214116, 0.01770824)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.01381, 0.0177257, 0.01478172)
# cupyx.scipy.sparse.csr_matrix sparse.GCXS (0.0027798, 0.0038795, 0.00313166)
# cupyx.scipy.sparse.csr_matrix sparse.COO (0.0296321, 0.0322782, 0.03076698)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.0019796, 0.0022753, 0.00219811)
# numpy.matrix scipy.sparse.csc_matrix (0.0821893, 0.0921608, 0.08562059)
# numpy.matrix sparse.DOK (0.3629104, 0.4094051, 0.38622755)
# numpy.matrix cupyx.scipy.sparse.coo_matrix (0.0273294, 0.0836549, 0.04382591)
# numpy.matrix scipy.sparse.csr_matrix (0.0742159, 0.0868003, 0.08020001)
# numpy.matrix cupy (0.0090436, 0.0104253, 0.00930196)
# numpy.matrix cuda (0.006204, 0.0077726, 0.00666705)
# numpy.matrix numpy (0.00621, 0.014866, 0.00819635)
# numpy.matrix cupyx.scipy.sparse.csr_matrix (0.025233, 0.0283145, 0.0261312)
# numpy.matrix numpy.matrix (6e-07, 9e-07, 6.5e-07)
# numpy.matrix scipy.sparse.coo_matrix (0.071656, 0.0850677, 0.07484995)
# numpy.matrix sparse.GCXS (0.0803377, 0.0992902, 0.08768329)
# numpy.matrix sparse.COO (0.0516709, 0.0710515, 0.0599519)
# numpy.matrix cupyx.scipy.sparse.csc_matrix (0.0249918, 0.0604476, 0.04084738)
# scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.0086485, 0.0221693, 0.01241523)
# scipy.sparse.coo_matrix sparse.DOK (0.6550234, 0.725933, 0.68932816)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (0.0111038, 0.0390506, 0.02920637)
# scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.0035821, 0.0041701, 0.00376677)
# scipy.sparse.coo_matrix cupy (0.1194782, 0.1213831, 0.12038468)
# scipy.sparse.coo_matrix cuda (0.0058952, 0.006301, 0.00611036)
# scipy.sparse.coo_matrix numpy (0.0058252, 0.0077239, 0.00636043)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.0095293, 0.021248, 0.01180241)
# scipy.sparse.coo_matrix numpy.matrix (0.0121131, 0.0140226, 0.01291071)
# scipy.sparse.coo_matrix scipy.sparse.coo_matrix (6e-07, 9e-07, 6.6e-07)
# scipy.sparse.coo_matrix sparse.GCXS (0.0037184, 0.0043698, 0.00395217)
# scipy.sparse.coo_matrix sparse.COO (0.0012264, 0.0014494, 0.00128454)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.0159557, 0.0244158, 0.01739878)
# sparse.GCXS scipy.sparse.csc_matrix (0.3790743, 0.3961189, 0.38719814)
# sparse.GCXS sparse.DOK (0.75395, 0.8455135, 0.80167217)
# sparse.GCXS cupyx.scipy.sparse.coo_matrix (0.5007797, 0.5556644, 0.52250334)
# sparse.GCXS scipy.sparse.csr_matrix (0.3701213, 0.392448, 0.37709386)
# sparse.GCXS cupy (0.0515864, 0.0675278, 0.05500747)
# sparse.GCXS cuda (0.0484152, 0.0637874, 0.05242294)
# sparse.GCXS numpy (0.0485415, 0.0673526, 0.05339986)
# sparse.GCXS cupyx.scipy.sparse.csr_matrix (0.4745064, 0.5110111, 0.48872876)
# sparse.GCXS numpy.matrix (0.0552891, 0.0741293, 0.05962629)
# sparse.GCXS scipy.sparse.coo_matrix (0.3786859, 0.4068373, 0.3914773)
# sparse.GCXS sparse.GCXS (6e-07, 1e-06, 7.1e-07)
# sparse.GCXS sparse.COO (0.0334137, 0.0534609, 0.03642134)
# sparse.GCXS cupyx.scipy.sparse.csc_matrix (0.4655356, 0.502234, 0.48377229)
# sparse.COO scipy.sparse.csc_matrix (0.0295591, 0.0461359, 0.0324796)
# sparse.COO sparse.DOK (0.7199213, 0.7621357, 0.73635922)
# sparse.COO cupyx.scipy.sparse.coo_matrix (0.0519713, 0.0588094, 0.05414041)
# sparse.COO scipy.sparse.csr_matrix (0.0202965, 0.0296734, 0.02293617)
# sparse.COO cupy (0.0172934, 0.0189004, 0.01775059)
# sparse.COO cuda (0.0146999, 0.0297368, 0.0172146)
# sparse.COO numpy (0.0145185, 0.0167166, 0.01501184)
# sparse.COO cupyx.scipy.sparse.csr_matrix (0.0281877, 0.0456544, 0.03100931)
# sparse.COO numpy.matrix (0.0213575, 0.0250846, 0.02309117)
# sparse.COO scipy.sparse.coo_matrix (0.0188841, 0.0279795, 0.02206325)
# sparse.COO sparse.GCXS (0.030373, 0.0438313, 0.03331701)
# sparse.COO sparse.COO (6e-07, 1e-06, 7.2e-07)
# sparse.COO cupyx.scipy.sparse.csc_matrix (0.0350899, 0.0484041, 0.03927987)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csc_matrix (0.0103765, 0.011348, 0.01082002)
# cupyx.scipy.sparse.csc_matrix sparse.DOK (0.7930683, 0.8392052, 0.81606757)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.0076536, 0.0534059, 0.02791661)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.006116, 0.0064287, 0.00620633)
# cupyx.scipy.sparse.csc_matrix cupy (0.0712163, 0.0736693, 0.07202113)
# cupyx.scipy.sparse.csc_matrix cuda (0.0099635, 0.0109106, 0.01021739)
# cupyx.scipy.sparse.csc_matrix numpy (0.0097536, 0.0195302, 0.01122473)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.0031063, 0.0033368, 0.0032001)
# cupyx.scipy.sparse.csc_matrix numpy.matrix (0.0603735, 0.0653556, 0.06228253)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.0141263, 0.0180002, 0.0149932)
# cupyx.scipy.sparse.csc_matrix sparse.GCXS (0.0033115, 0.0036462, 0.00343712)
# cupyx.scipy.sparse.csc_matrix sparse.COO (0.1132611, 0.1349199, 0.12067594)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (7e-07, 7.4e-06, 1.41e-06)

# %%
names = {
    NUMPY: 'NUMPY',
    NUMPY_MATRIX: 'NUMPY_MATRIX',
    CUDA: 'CUDA',
    CUPY: 'CUPY',
    SPARSE_COO: 'SPARSE_COO',
    SPARSE_GCXS: 'SPARSE_GCXS',
    SPARSE_DOK: 'SPARSE_DOK',
    SCIPY_COO: 'SCIPY_COO',
    SCIPY_CSR: 'SCIPY_CSR',
    SCIPY_CSC: 'SCIPY_CSC',
    CUPY_SCIPY_COO: 'CUPY_SCIPY_COO',
    CUPY_SCIPY_CSR: 'CUPY_SCIPY_CSR',
    CUPY_SCIPY_CSC: 'CUPY_SCIPY_CSC',
}

# %%
for left in BACKENDS:
    for right in BACKENDS:
        print(f"    ({names[left]}, {names[right]}): {b[(left, right)][2]},")
# Out:
#     (SCIPY_CSC, SCIPY_CSC): 6.8e-07,
#     (SCIPY_CSC, SPARSE_DOK): 0.79008641,
#     (SCIPY_CSC, CUPY_SCIPY_COO): 0.01557962,
#     (SCIPY_CSC, SCIPY_CSR): 0.00550373,
#     (SCIPY_CSC, CUPY): 0.07368527,
#     (SCIPY_CSC, CUDA): 0.00645836,
#     (SCIPY_CSC, NUMPY): 0.00646419,
#     (SCIPY_CSC, CUPY_SCIPY_CSR): 0.00894698,
#     (SCIPY_CSC, NUMPY_MATRIX): 0.06175063,
#     (SCIPY_CSC, SCIPY_COO): 0.00913096,
#     (SCIPY_CSC, SPARSE_GCXS): 1.715e-05,
#     (SCIPY_CSC, SPARSE_COO): 0.10771111,
#     (SCIPY_CSC, CUPY_SCIPY_CSC): 0.00276772,
#     (SPARSE_DOK, SCIPY_CSC): 0.42924186,
#     (SPARSE_DOK, SPARSE_DOK): 8.1e-07,
#     (SPARSE_DOK, CUPY_SCIPY_COO): 0.45422632,
#     (SPARSE_DOK, SCIPY_CSR): 0.41378311,
#     (SPARSE_DOK, CUPY): 0.12193486,
#     (SPARSE_DOK, CUDA): 0.11697014,
#     (SPARSE_DOK, NUMPY): 0.111815,
#     (SPARSE_DOK, CUPY_SCIPY_CSR): 0.45438094,
#     (SPARSE_DOK, NUMPY_MATRIX): 0.12303009,
#     (SPARSE_DOK, SCIPY_COO): 0.40668993,
#     (SPARSE_DOK, SPARSE_GCXS): 0.42601204,
#     (SPARSE_DOK, SPARSE_COO): 0.39792751,
#     (SPARSE_DOK, CUPY_SCIPY_CSC): 0.42898774,
#     (CUPY_SCIPY_COO, SCIPY_CSC): 0.0520641,
#     (CUPY_SCIPY_COO, SPARSE_DOK): 0.69566436,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_COO): 8e-07,
#     (CUPY_SCIPY_COO, SCIPY_CSR): 0.05163085,
#     (CUPY_SCIPY_COO, CUPY): 0.11410962,
#     (CUPY_SCIPY_COO, CUDA): 0.01298642,
#     (CUPY_SCIPY_COO, NUMPY): 0.01314296,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSR): 0.04786648,
#     (CUPY_SCIPY_COO, NUMPY_MATRIX): 0.01981244,
#     (CUPY_SCIPY_COO, SCIPY_COO): 0.00711411,
#     (CUPY_SCIPY_COO, SPARSE_GCXS): 0.0518312,
#     (CUPY_SCIPY_COO, SPARSE_COO): 0.0226392,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSC): 0.04807331,
#     (SCIPY_CSR, SCIPY_CSC): 0.01132071,
#     (SCIPY_CSR, SPARSE_DOK): 0.69419015,
#     (SCIPY_CSR, CUPY_SCIPY_COO): 0.03507685,
#     (SCIPY_CSR, SCIPY_CSR): 8.1e-07,
#     (SCIPY_CSR, CUPY): 0.0736361,
#     (SCIPY_CSR, CUDA): 0.00702799,
#     (SCIPY_CSR, NUMPY): 0.00613211,
#     (SCIPY_CSR, CUPY_SCIPY_CSR): 0.00214472,
#     (SCIPY_CSR, NUMPY_MATRIX): 0.01560373,
#     (SCIPY_CSR, SCIPY_COO): 0.00780115,
#     (SCIPY_CSR, SPARSE_GCXS): 1.791e-05,
#     (SCIPY_CSR, SPARSE_COO): 0.01731952,
#     (SCIPY_CSR, CUPY_SCIPY_CSC): 0.01247452,
#     (CUPY, SCIPY_CSC): 0.08765124,
#     (CUPY, SPARSE_DOK): 0.44793429,
#     (CUPY, CUPY_SCIPY_COO): 0.01578986,
#     (CUPY, SCIPY_CSR): 0.08288962,
#     (CUPY, CUPY): 8.1e-07,
#     (CUPY, CUDA): 0.011692,
#     (CUPY, NUMPY): 0.01315366,
#     (CUPY, CUPY_SCIPY_CSR): 0.01067939,
#     (CUPY, NUMPY_MATRIX): 0.01975819,
#     (CUPY, SCIPY_COO): 0.07855287,
#     (CUPY, SPARSE_GCXS): 0.09928033,
#     (CUPY, SPARSE_COO): 0.07420958,
#     (CUPY, CUPY_SCIPY_CSC): 0.01580088,
#     (CUDA, SCIPY_CSC): 0.07511825,
#     (CUDA, SPARSE_DOK): 0.42874134,
#     (CUDA, CUPY_SCIPY_COO): 0.02223272,
#     (CUDA, SCIPY_CSR): 0.07167406,
#     (CUDA, CUPY): 0.0062838,
#     (CUDA, CUDA): 7.5e-07,
#     (CUDA, NUMPY): 8e-07,
#     (CUDA, CUPY_SCIPY_CSR): 0.02201833,
#     (CUDA, NUMPY_MATRIX): 0.00721113,
#     (CUDA, SCIPY_COO): 0.06756767,
#     (CUDA, SPARSE_GCXS): 0.08923092,
#     (CUDA, SPARSE_COO): 0.05519825,
#     (CUDA, CUPY_SCIPY_CSC): 0.03305383,
#     (NUMPY, SCIPY_CSC): 0.07595573,
#     (NUMPY, SPARSE_DOK): 0.42557287,
#     (NUMPY, CUPY_SCIPY_COO): 0.03367578,
#     (NUMPY, SCIPY_CSR): 0.07286735,
#     (NUMPY, CUPY): 0.00426659,
#     (NUMPY, CUDA): 8.1e-07,
#     (NUMPY, NUMPY): 7.6e-07,
#     (NUMPY, CUPY_SCIPY_CSR): 0.02202718,
#     (NUMPY, NUMPY_MATRIX): 0.00715483,
#     (NUMPY, SCIPY_COO): 0.06798563,
#     (NUMPY, SPARSE_GCXS): 0.08982199,
#     (NUMPY, SPARSE_COO): 0.05319294,
#     (NUMPY, CUPY_SCIPY_CSC): 0.03394102,
#     (CUPY_SCIPY_CSR, SCIPY_CSC): 0.00628662,
#     (CUPY_SCIPY_CSR, SPARSE_DOK): 0.6935086,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_COO): 0.01812139,
#     (CUPY_SCIPY_CSR, SCIPY_CSR): 0.00290519,
#     (CUPY_SCIPY_CSR, CUPY): 0.07112426,
#     (CUPY_SCIPY_CSR, CUDA): 0.0088542,
#     (CUPY_SCIPY_CSR, NUMPY): 0.00929009,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSR): 8.4e-07,
#     (CUPY_SCIPY_CSR, NUMPY_MATRIX): 0.01770824,
#     (CUPY_SCIPY_CSR, SCIPY_COO): 0.01478172,
#     (CUPY_SCIPY_CSR, SPARSE_GCXS): 0.00313166,
#     (CUPY_SCIPY_CSR, SPARSE_COO): 0.03076698,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSC): 0.00219811,
#     (NUMPY_MATRIX, SCIPY_CSC): 0.08562059,
#     (NUMPY_MATRIX, SPARSE_DOK): 0.38622755,
#     (NUMPY_MATRIX, CUPY_SCIPY_COO): 0.04382591,
#     (NUMPY_MATRIX, SCIPY_CSR): 0.08020001,
#     (NUMPY_MATRIX, CUPY): 0.00930196,
#     (NUMPY_MATRIX, CUDA): 0.00666705,
#     (NUMPY_MATRIX, NUMPY): 0.00819635,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSR): 0.0261312,
#     (NUMPY_MATRIX, NUMPY_MATRIX): 6.5e-07,
#     (NUMPY_MATRIX, SCIPY_COO): 0.07484995,
#     (NUMPY_MATRIX, SPARSE_GCXS): 0.08768329,
#     (NUMPY_MATRIX, SPARSE_COO): 0.0599519,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSC): 0.04084738,
#     (SCIPY_COO, SCIPY_CSC): 0.01241523,
#     (SCIPY_COO, SPARSE_DOK): 0.68932816,
#     (SCIPY_COO, CUPY_SCIPY_COO): 0.02920637,
#     (SCIPY_COO, SCIPY_CSR): 0.00376677,
#     (SCIPY_COO, CUPY): 0.12038468,
#     (SCIPY_COO, CUDA): 0.00611036,
#     (SCIPY_COO, NUMPY): 0.00636043,
#     (SCIPY_COO, CUPY_SCIPY_CSR): 0.01180241,
#     (SCIPY_COO, NUMPY_MATRIX): 0.01291071,
#     (SCIPY_COO, SCIPY_COO): 6.6e-07,
#     (SCIPY_COO, SPARSE_GCXS): 0.00395217,
#     (SCIPY_COO, SPARSE_COO): 0.00128454,
#     (SCIPY_COO, CUPY_SCIPY_CSC): 0.01739878,
#     (SPARSE_GCXS, SCIPY_CSC): 0.38719814,
#     (SPARSE_GCXS, SPARSE_DOK): 0.80167217,
#     (SPARSE_GCXS, CUPY_SCIPY_COO): 0.52250334,
#     (SPARSE_GCXS, SCIPY_CSR): 0.37709386,
#     (SPARSE_GCXS, CUPY): 0.05500747,
#     (SPARSE_GCXS, CUDA): 0.05242294,
#     (SPARSE_GCXS, NUMPY): 0.05339986,
#     (SPARSE_GCXS, CUPY_SCIPY_CSR): 0.48872876,
#     (SPARSE_GCXS, NUMPY_MATRIX): 0.05962629,
#     (SPARSE_GCXS, SCIPY_COO): 0.3914773,
#     (SPARSE_GCXS, SPARSE_GCXS): 7.1e-07,
#     (SPARSE_GCXS, SPARSE_COO): 0.03642134,
#     (SPARSE_GCXS, CUPY_SCIPY_CSC): 0.48377229,
#     (SPARSE_COO, SCIPY_CSC): 0.0324796,
#     (SPARSE_COO, SPARSE_DOK): 0.73635922,
#     (SPARSE_COO, CUPY_SCIPY_COO): 0.05414041,
#     (SPARSE_COO, SCIPY_CSR): 0.02293617,
#     (SPARSE_COO, CUPY): 0.01775059,
#     (SPARSE_COO, CUDA): 0.0172146,
#     (SPARSE_COO, NUMPY): 0.01501184,
#     (SPARSE_COO, CUPY_SCIPY_CSR): 0.03100931,
#     (SPARSE_COO, NUMPY_MATRIX): 0.02309117,
#     (SPARSE_COO, SCIPY_COO): 0.02206325,
#     (SPARSE_COO, SPARSE_GCXS): 0.03331701,
#     (SPARSE_COO, SPARSE_COO): 7.2e-07,
#     (SPARSE_COO, CUPY_SCIPY_CSC): 0.03927987,
#     (CUPY_SCIPY_CSC, SCIPY_CSC): 0.01082002,
#     (CUPY_SCIPY_CSC, SPARSE_DOK): 0.81606757,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_COO): 0.02791661,
#     (CUPY_SCIPY_CSC, SCIPY_CSR): 0.00620633,
#     (CUPY_SCIPY_CSC, CUPY): 0.07202113,
#     (CUPY_SCIPY_CSC, CUDA): 0.01021739,
#     (CUPY_SCIPY_CSC, NUMPY): 0.01122473,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSR): 0.0032001,
#     (CUPY_SCIPY_CSC, NUMPY_MATRIX): 0.06228253,
#     (CUPY_SCIPY_CSC, SCIPY_COO): 0.0149932,
#     (CUPY_SCIPY_CSC, SPARSE_GCXS): 0.00343712,
#     (CUPY_SCIPY_CSC, SPARSE_COO): 0.12067594,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSC): 1.41e-06,
